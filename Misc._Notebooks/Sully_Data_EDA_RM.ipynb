# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import inf

# %%
colnames=['timestamp', 'game_name', 'hourly_channels', 'hourly_viewership']
sully = pd.read_csv('data/Natasha.csv', names=colnames, header=None)

# %%
sully.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2092036 entries, 0 to 2092035
# Data columns (total 4 columns):
# timestamp            object
# game_name            object
# hourly_channels      int64
# hourly_viewership    int64
# dtypes: int64(2), object(2)
# memory usage: 63.8+ MB

# %%
sully.head()
# Out:
#                  timestamp                         game_name  hourly_channels  \
# 0  2019-04-22 00:00:00.000                 League of Legends             3160
# 1  2019-04-22 00:00:00.000  Counter-Strike: Global Offensive             1246
# 2  2019-04-22 00:00:00.000           Ultra Street Fighter IV                2
# 3  2019-04-22 00:00:00.000                       Hearthstone              224
# 4  2019-04-22 00:00:00.000                            Dota 2              467
#
#    hourly_viewership
# 0              97898
# 1              54330
# 2                144
# 3              33632
# 4              27497

# %%
sully.timestamp
# Out:
# 0          2019-04-22 00:00:00.000
# 1          2019-04-22 00:00:00.000
# 2          2019-04-22 00:00:00.000
# 3          2019-04-22 00:00:00.000
# 4          2019-04-22 00:00:00.000
# 5          2019-04-22 00:00:00.000
# 6          2019-04-22 00:00:00.000
# 7          2019-04-22 00:00:00.000
# 8          2019-04-22 00:00:00.000
# 9          2019-04-22 00:00:00.000
# 10         2019-04-22 00:00:00.000
# 11         2019-04-22 00:00:00.000
# 12         2019-04-22 00:00:00.000
# 13         2019-04-22 00:00:00.000
# 14         2019-04-22 00:00:00.000
# 15         2019-04-22 00:00:00.000
# 16         2019-04-22 00:00:00.000
# 17         2019-04-22 00:00:00.000
# 18         2019-04-22 00:00:00.000
# 19         2019-04-22 00:00:00.000
# 20         2019-04-22 00:00:00.000
# 21         2019-04-22 00:00:00.000
# 22         2019-04-22 00:00:00.000
# 23         2019-04-22 00:00:00.000
# 24         2019-04-22 00:00:00.000
# 25         2019-04-22 00:00:00.000
# 26         2019-04-22 00:00:00.000
# 27         2019-04-22 00:00:00.000
# 28         2019-04-22 00:00:00.000
# 29         2019-04-22 00:00:00.000
#                     ...
# 2092006    2019-05-31 00:00:00.000
# 2092007    2019-05-31 00:00:00.000
# 2092008    2019-05-31 00:00:00.000
# 2092009    2019-05-31 00:00:00.000
# 2092010    2019-05-31 00:00:00.000
# 2092011    2019-05-31 00:00:00.000
# 2092012    2019-05-31 00:00:00.000
# 2092013    2019-05-31 00:00:00.000
# 2092014    2019-05-31 00:00:00.000
# 2092015    2019-05-31 00:00:00.000
# 2092016    2019-05-31 00:00:00.000
# 2092017    2019-05-31 00:00:00.000
# 2092018    2019-05-31 00:00:00.000
# 2092019    2019-05-31 00:00:00.000
# 2092020    2019-05-31 00:00:00.000
# 2092021    2019-05-31 00:00:00.000
# 2092022    2019-05-31 00:00:00.000
# 2092023    2019-05-31 00:00:00.000
# 2092024    2019-05-31 00:00:00.000
# 2092025    2019-05-31 00:00:00.000
# 2092026    2019-05-31 00:00:00.000
# 2092027    2019-05-31 00:00:00.000
# 2092028    2019-05-31 00:00:00.000
# 2092029    2019-05-31 00:00:00.000
# 2092030    2019-05-31 00:00:00.000
# 2092031    2019-05-31 00:00:00.000
# 2092032    2019-05-31 00:00:00.000
# 2092033    2019-05-31 00:00:00.000
# 2092034    2019-05-31 00:00:00.000
# 2092035    2019-05-31 00:00:00.000
# Name: timestamp, Length: 2092036, dtype: object

# %%
sully.describe()
# Out:
#        hourly_channels  hourly_viewership
# count     2.092036e+06       2.092036e+06
# mean      1.996948e+01       5.517764e+02
# std       2.405983e+02       6.378626e+03
# min       1.000000e+00       0.000000e+00
# 25%       1.000000e+00       2.000000e+00
# 50%       1.000000e+00       6.000000e+00
# 75%       4.000000e+00       3.100000e+01
# max       4.169200e+04       7.039990e+05

# %%
sully['timestamp'] = pd.to_datetime(sully['timestamp'])

# %%
sully.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2092036 entries, 0 to 2092035
# Data columns (total 4 columns):
# timestamp            datetime64[ns]
# game_name            object
# hourly_channels      int64
# hourly_viewership    int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 63.8+ MB

# %%
sully.plot.line(x = 'timestamp', y = 'hourly_viewership');

# %%
sully.plot.line(x = 'timestamp', y = 'hourly_channels');

# %%
trend_views = sully.groupby('game_name').mean().sort_values(by = 'hourly_viewership', ascending = False)

# %%
trend_views.head(10).plot.bar(y = 'hourly_viewership');

# %%
trend_channel = sully.groupby('game_name').mean().sort_values(by = 'hourly_channels', ascending = False)

# %%
trend_channel.head(10).plot.bar(y = 'hourly_channels');

# %%
sully.sample()
# Out:
#                   timestamp   game_name  hourly_channels  hourly_viewership
# 1843939 2019-05-26 11:00:00  Black Mesa                1                  1

# %%
trend_channel.sample()
# Out:
#                                                     hourly_channels  \
# game_name
# Lobotomy Corporation | Monster Management Simul...         2.252571
#
#                                                     hourly_viewership
# game_name
# Lobotomy Corporation | Monster Management Simul...          26.731429

# %%
trend_views.sample()
# Out:
#                          hourly_channels  hourly_viewership
# game_name
# Conker: Live & Reloaded         1.009346          10.934579

# %%
trend_channel['views_channels_ratio'] = trend_channel['hourly_viewership']/trend_channel['hourly_channels']

# %%
trend_channel.sort_values(by='views_channels_ratio', ascending=True, na_position ='last').head()
# Out:
#                                                     hourly_channels  \
# game_name
# Sister Slave: Faithful Girl's Slave Training                    1.0
# Driving Simulator 2009                                          1.0
# Worms Crazy Golf                                                1.0
# Gakkou de atta Kowai Hanashi                                    1.0
# World Series of Poker 2008: Battle for the Brac...              1.0
#
#                                                     hourly_viewership  \
# game_name
# Sister Slave: Faithful Girl's Slave Training                      0.0
# Driving Simulator 2009                                            0.0
# Worms Crazy Golf                                                  0.0
# Gakkou de atta Kowai Hanashi                                      0.0
# World Series of Poker 2008: Battle for the Brac...                0.0
#
#                                                     views_channels_ratio
# game_name
# Sister Slave: Faithful Girl's Slave Training                         0.0
# Driving Simulator 2009                                               0.0
# Worms Crazy Golf                                                     0.0
# Gakkou de atta Kowai Hanashi                                         0.0
# World Series of Poker 2008: Battle for the Brac...                   0.0

# %%
#replace inf values with 0
trend_channel['views_channels_ratio'][trend_channel['views_channels_ratio'] == inf] = 0

# %%
trend_channel.sort_values(by=['views_channels_ratio'], ascending=False)
# Out:
#                                                     hourly_channels  \
# game_name
# in My MIND.                                                1.000000
# Decathlete                                                 1.000000
# The Spookening                                             1.666667
# Hoshi wo Miru Hito                                         2.000000
# Sleep Is Death                                             1.000000
# Mashed: Drive to Survive                                   1.000000
# Caveman World: Mountains of Unga Boonga                    1.000000
# Omega Labyrinth Z                                          1.000000
# Defection                                                  2.500000
# Final Zone                                                 1.000000
# Night Warriors: Darkstalkers' Revenge                      1.000000
# Legend of Hero Tonma                                       1.000000
# Curse of the Azure Bonds                                   1.800000
# Dragon Egg                                                 1.000000
# Clam Man                                                   1.250000
# Gotta Go                                                   1.000000
# Sinbad: Legend of the Seven Seas                           1.000000
# Just For Killing Time R(-18)PG                             1.000000
# Crazy Bus                                                  1.000000
# ReWorld Online                                             1.000000
# Not in Heaven                                              1.700000
# StreetPass Mii Plaza                                       1.000000
# Wai Wai World 2: SOS Parsley-jou!                          1.000000
# My Twin Brother Made Me Crossdress As Him and N...         1.162791
# Quest RPG: Brian's Journey                                 1.294118
# Screamer 2                                                 1.000000
# Men of Valor                                               1.000000
# Last Bronx                                                 1.000000
# Super Hydlide                                              1.555556
# Corruption                                                 1.000000
# ...                                                             ...
# Prismatic Solid                                            1.000000
# Madden NFL 06                                              1.000000
# Best of Best                                               1.000000
# Pro Gamer Manager                                          1.000000
# Machines                                                   1.000000
# MLB 9 Innings 16                                           1.000000
# MOP: Operation Cleanup                                     1.000000
# MTV: Music Generator                                       1.000000
# MX Nitro                                                   1.000000
# MVP 07 NCAA Baseball                                       1.000000
# Lynn                                                       1.000000
# Puzzle Quest Magic: The Gathering                          1.000000
# Pro Cycling Manager 2016                                   1.000000
# Big Win Baseball                                           1.000000
# Beyond Atlantis II                                         1.000000
# Beyblade: Burst God                                        1.000000
# Beowulf: The Game                                          1.000000
# Bi-Fi 2: Action in Hollywood                               1.000000
# Beer Ranger                                                1.000000
# Pro Yakyuu Team o Tsukurou!                                1.000000
# Ben 10: Galactic Racing                                    1.000000
# Below Kryll                                                1.000000
# Biomotor Unitron                                           1.000000
# Bio Force Ape                                              1.000000
# Project Remedium                                           1.000000
# Big Money! Deluxe                                          1.000000
# Big Job                                                    1.000000
# Pyramid of Doom                                            1.000000
# Bible Buffet                                               1.000000
# Sister Slave: Faithful Girl's Slave Training               1.000000
#
#                                                     hourly_viewership  \
# game_name
# in My MIND.                                              24306.000000
# Decathlete                                                9489.000000
# The Spookening                                           14431.666667
# Hoshi wo Miru Hito                                       16468.500000
# Sleep Is Death                                            7981.000000
# Mashed: Drive to Survive                                  5989.000000
# Caveman World: Mountains of Unga Boonga                   5837.000000
# Omega Labyrinth Z                                         5163.285714
# Defection                                                11832.000000
# Final Zone                                                4336.000000
# Night Warriors: Darkstalkers' Revenge                     4212.500000
# Legend of Hero Tonma                                      4083.000000
# Curse of the Azure Bonds                                  6641.800000
# Dragon Egg                                                3640.000000
# Clam Man                                                  3730.250000
# Gotta Go                                                  2692.000000
# Sinbad: Legend of the Seven Seas                          2652.000000
# Just For Killing Time R(-18)PG                            2559.333333
# Crazy Bus                                                 2324.333333
# ReWorld Online                                            2274.000000
# Not in Heaven                                             3757.200000
# StreetPass Mii Plaza                                      2207.500000
# Wai Wai World 2: SOS Parsley-jou!                         2134.000000
# My Twin Brother Made Me Crossdress As Him and N...        2460.651163
# Quest RPG: Brian's Journey                                2680.882353
# Screamer 2                                                2013.500000
# Men of Valor                                              2002.500000
# Last Bronx                                                1992.250000
# Super Hydlide                                             2999.555556
# Corruption                                                1858.033333
# ...                                                               ...
# Prismatic Solid                                              0.000000
# Madden NFL 06                                                0.000000
# Best of Best                                                 0.000000
# Pro Gamer Manager                                            0.000000
# Machines                                                     0.000000
# MLB 9 Innings 16                                             0.000000
# MOP: Operation Cleanup                                       0.000000
# MTV: Music Generator                                         0.000000
# MX Nitro                                                     0.000000
# MVP 07 NCAA Baseball                                         0.000000
# Lynn                                                         0.000000
# Puzzle Quest Magic: The Gathering                            0.000000
# Pro Cycling Manager 2016                                     0.000000
# Big Win Baseball                                             0.000000
# Beyond Atlantis II                                           0.000000
# Beyblade: Burst God                                          0.000000
# Beowulf: The Game                                            0.000000
# Bi-Fi 2: Action in Hollywood                                 0.000000
# Beer Ranger                                                  0.000000
# Pro Yakyuu Team o Tsukurou!                                  0.000000
# Ben 10: Galactic Racing                                      0.000000
# Below Kryll                                                  0.000000
# Biomotor Unitron                                             0.000000
# Bio Force Ape                                                0.000000
# Project Remedium                                             0.000000
# Big Money! Deluxe                                            0.000000
# Big Job                                                      0.000000
# Pyramid of Doom                                              0.000000
# Bible Buffet                                                 0.000000
# Sister Slave: Faithful Girl's Slave Training                 0.000000
#
#                                                     views_channels_ratio
# game_name
# in My MIND.                                                 24306.000000
# Decathlete                                                   9489.000000
# The Spookening                                               8659.000000
# Hoshi wo Miru Hito                                           8234.250000
# Sleep Is Death                                               7981.000000
# Mashed: Drive to Survive                                     5989.000000
# Caveman World: Mountains of Unga Boonga                      5837.000000
# Omega Labyrinth Z                                            5163.285714
# Defection                                                    4732.800000
# Final Zone                                                   4336.000000
# Night Warriors: Darkstalkers' Revenge                        4212.500000
# Legend of Hero Tonma                                         4083.000000
# Curse of the Azure Bonds                                     3689.888889
# Dragon Egg                                                   3640.000000
# Clam Man                                                     2984.200000
# Gotta Go                                                     2692.000000
# Sinbad: Legend of the Seven Seas                             2652.000000
# Just For Killing Time R(-18)PG                               2559.333333
# Crazy Bus                                                    2324.333333
# ReWorld Online                                               2274.000000
# Not in Heaven                                                2210.117647
# StreetPass Mii Plaza                                         2207.500000
# Wai Wai World 2: SOS Parsley-jou!                            2134.000000
# My Twin Brother Made Me Crossdress As Him and N...           2116.160000
# Quest RPG: Brian's Journey                                   2071.590909
# Screamer 2                                                   2013.500000
# Men of Valor                                                 2002.500000
# Last Bronx                                                   1992.250000
# Super Hydlide                                                1928.285714
# Corruption                                                   1858.033333
# ...                                                                  ...
# Prismatic Solid                                                 0.000000
# Madden NFL 06                                                   0.000000
# Best of Best                                                    0.000000
# Pro Gamer Manager                                               0.000000
# Machines                                                        0.000000
# MLB 9 Innings 16                                                0.000000
# MOP: Operation Cleanup                                          0.000000
# MTV: Music Generator                                            0.000000
# MX Nitro                                                        0.000000
# MVP 07 NCAA Baseball                                            0.000000
# Lynn                                                            0.000000
# Puzzle Quest Magic: The Gathering                               0.000000
# Pro Cycling Manager 2016                                        0.000000
# Big Win Baseball                                                0.000000
# Beyond Atlantis II                                              0.000000
# Beyblade: Burst God                                             0.000000
# Beowulf: The Game                                               0.000000
# Bi-Fi 2: Action in Hollywood                                    0.000000
# Beer Ranger                                                     0.000000
# Pro Yakyuu Team o Tsukurou!                                     0.000000
# Ben 10: Galactic Racing                                         0.000000
# Below Kryll                                                     0.000000
# Biomotor Unitron                                                0.000000
# Bio Force Ape                                                   0.000000
# Project Remedium                                                0.000000
# Big Money! Deluxe                                               0.000000
# Big Job                                                         0.000000
# Pyramid of Doom                                                 0.000000
# Bible Buffet                                                    0.000000
# Sister Slave: Faithful Girl's Slave Training                    0.000000
#
# [22249 rows x 3 columns]

# %%
#find a gap 
#aggregate by day, week, (40 days)
#for every week of FN, is the ratio growing or shrinking
#more viewers/fewer channels

# %%
#viewers by day

# %%
#graph viewership growth by time

# %%
#graph stream growth by time

# %%
#graph game activity by time
# sully['hourly_viewership']

# %%
from pandas import Series
from matplotlib import pyplot
# series = Series.from_csv('daily-minimum-temperatures.csv', header=0)
# series.plot()
# pyplot.show()

# %%
import matplotlib.pyplot as plt
# plot a line, implicitly creating a subplot(111)
test = [item for item in zip(sully.timestamp,sully.hourly_viewership)]

# series = Series(test)
# series.plot()
x = pd.DataFrame(test)
x.head()
# Out:
#                          0      1
# 0  2019-04-22 00:00:00.000  97898
# 1  2019-04-22 00:00:00.000  54330
# 2  2019-04-22 00:00:00.000    144
# 3  2019-04-22 00:00:00.000  33632
# 4  2019-04-22 00:00:00.000  27497

# %%
# now create a subplot which represents the top plot of a grid
# with 2 rows and 1 column. Since this subplot will overlap the
# first, the plot (and its axes) previously created, will be removed
plt.subplot(211);
