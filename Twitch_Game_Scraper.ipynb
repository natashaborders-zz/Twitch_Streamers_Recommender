# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import random

import time
import os
import sys
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

url = 'https://www.twitch.tv/robots.txt'
response  = requests.get(url)
print(response.text)
# Out:
# User-Agent: *
# Allow: /
# Allow: /directory
# Allow: /directory/all
# Allow: /directory/*
# Allow: /videos/week
# Allow: /.well-known/assetlinks.json
# Disallow: /user/*
# Disallow: /admin/*
# Disallow: /login$
# Disallow: /signup$
# Disallow: /message/*
#
# Sitemap: https://www.twitch.tv/sitemap_index.xml.gz
# Sitemap: https://www.twitch.tv/sitemap_naver_index.xml.gz

# %%
import sys
import requests
from bs4 import BeautifulSoup

url = 'https://www.twitch.tv/directory'

user_agent = {'User-agent': 'Mozilla/5.0'}
response  = requests.get(url, headers = user_agent)

# %%
ua = UserAgent()
user_agent = {'User-agent': ua.random}
print(user_agent)

response  = requests.get(url, headers = user_agent)
print(response.text)
# Out:
# {'User-agent': 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0'}
# <!DOCTYPE html><html class="tw-root--hover"><head><meta charset="utf-8"><title>Twitch</title><meta property='og:site_name' content='Twitch'><meta property='fb:app_id' content='161273083968709'><meta property='twitter:site' content='@twitch'><meta property='og:title' content='Twitch'><meta property='og:description' content='Twitch is the world&#39;s leading video platform and community for gamers.'><meta property='og:image' content='//www-cdn.jtvnw.net/images/twitch_logo3.jpg'><meta property='og:url' content='https://www.twitch.tv/directory'><meta property='og:type' content='website'><link rel='canonical' href='https://www.twitch.tv/directory'><link rel='alternate' href='https://m.twitch.tv/directory'><link rel="icon" href="https://static.twitchcdn.net/assets/favicon-75270f9df2b07174c23c.ico"><link rel="dns-prefetch" href="https://api.twitch.tv/"><link rel="dns-prefetch" href="https://passport.twitch.tv/"><link rel="dns-prefetch" href="https://static-cdn.jtvnw.net/"><link rel="preconnect" href="https://api.twitch.tv/"><link rel="preconnect" href="https://static-cdn.jtvnw.net/"><link rel="dns-prefetch" href="https://gql.twitch.tv/"><link rel="dns-prefetch" href="https://cvp.twitch.tv/"><link rel="dns-prefetch" href="https://irc-ws.chat.twitch.tv/"><link rel="dns-prefetch" href="https://player.twitch.tv/"><link rel="dns-prefetch" href="https://pubsub-edge.twitch.tv/"><link rel="dns-prefetch" href="https://static.twitchcdn.net/"><link rel="preconnect" href="https://gql.twitch.tv/"><link rel="preconnect" href="https://player.twitch.tv/"><link rel="preconnect" href="https://static.twitchcdn.net/"><link rel="preconnect" href="https://cvp.twitch.tv/"></head><body><div id="root" class="root"><style>html{font-size:62.5%}body{font-size:1.2rem}.root,body,html{margin:0;overflow:hidden;width:100%;height:100%;display:-webkit-box;display:-ms-flexbox;display:flex;-ms-flex-direction:column;flex-direction:column;position:relative}body.dark-theme{background-color:#19171c}.shell-nav{background:#6441a4;height:5rem;width:100%;position:absolute;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch}body.dark-theme .shell-nav{background:#4b367c}html.desktop-login .shell-nav{display:none}.shell-nav__logo{padding:1rem;display:inline-block;margin:0}.shell-nav__link{padding:2rem;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center}.shell-nav__link-list{display:flex}.shell-nav__link::after{content:'';height:.4rem;background:rgba(255,255,255,.2);border-radius:2px}.shell-nav__link--discovery::after{width:6.2rem}.shell-nav__link--browse::after{width:5.4rem}.shell-nav__link--follow::after{width:6.8rem}.shell-nav__link--follow{display:none}body.logged-in .shell-nav__link--follow{display:-webkit-box;display:-ms-flexbox;display:flex}.shell-nav__ellipsis{width:5rem;display:-webkit-box;display:-ms-flexbox;display:flex;display:none;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center}.shell__svg--navmore{fill:rgba(255,255,255,.4);height:2rem}.shell-nav__search-container{-webkit-box-flex:1;-ms-flex-positive:1;flex-grow:1;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center}.shell-nav__search{display:none;width:100%;max-width:40rem;height:3rem;margin:0 1rem;background:rgba(255,255,255,.4);border-radius:2px}.shell-nav__user-card{width:5rem;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;justify-content:flex-end;box-sizing:border-box}.shell-nav__user-card-avatar{margin-right:1rem;width:3rem;height:3rem;background:rgba(255,255,255,.15);-ms-flex-negative:0;flex-shrink:0;border-radius:2px}.shell-nav__user-auth{display:-webkit-box;display:-ms-flexbox;display:flex ...

# %% [markdown]
# ## Now to Selenium!
#
# ## What happens if I try to parse my gmail with `requests` and `BeautifulSoup`?

# %% [markdown]
# # Scraping Box Office Mojo with Selenium

# %%
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver 

driver = webdriver.Chrome(chromedriver)

matrix_url = "https://www.twitch.tv/directory"
driver.get(matrix_url) #opens the matrix in the dummy google chrome

# %%
# 'contains' will find a match on the text, in this case return b tag
game_list = []
num = 2
while num < 110:
    gross_selector = f'//*[@id="root"]/div/div[2]/div/main/div/div[3]/div/div/div/div[3]/div/div/div[1]/div[{num}]/div/div/div/div[1]/div/a/div[2]/div/div/h3'
    print(driver.find_element_by_xpath(gross_selector).text)
    game_list.append(driver.find_element_by_xpath(gross_selector).text)    
    time.sleep(.5+2*random.random())
    num+=1
# Out:
# Fortnite
# League of Legends
# Counter-Strike: Global Offensive
# Grand Theft Auto V
# Just Chatting
# World of Warcraft
# Rocket League
# Dota 2
# PLAYERUNKNOWN'S BATTLEGROUNDS
# Apex Legends
# Overwatch
# Super Smash Bros. Ultimate
# Auto Chess
# Call of Duty: Black Ops II
# Tom Clancy's Rainbow Six: Siege
# Battalion 1944
# PixARK
# Call of Duty: Black Ops 4
# Dead by Daylight
# Minecraft
# Total War: Three Kingdoms
# Hearthstone
# The Elder Scrolls Online
# Magic: The Gathering
# Art
# Destiny 2
# Void Bastards
# Dauntless
# NBA 2K19
# Music & Performing Arts
# Slots
# FIFA 19
# Escape From Tarkov
# Warhammer: Chaosbane
# Madden NFL 19
# FINAL FANTASY XIV Online
# Path of Exile
# Old School RuneScape
# Super Smash Bros. Melee
# Code Vein
# Deathgarden
# ASMR
# Rust
# Dark Souls II
# Hunt: Showdown
# The Elder Scrolls V: Skyrim
# StarCraft II
# Retro
# Diablo III: Reaper of Souls
# Black Desert Online
# Layers of Fear 2
# Talk Shows & Podcasts
# Super Mario 64
# Food & Drink
# Tibia
# Granblue Fantasy: Versus
# DayZ
# BaBa Is You
# Warcraft III: The Frozen Throne
# Smite
# Summoners War: Sky Arena
# Yoshi's Crafted World
# The Sims 4
# ARK
# Lineage II
# Halo: The Master Chief Collection
# VRChat
# Heroes of the Storm
# Mortal Kombat 11
# Human: Fall Flat
# Poker
# Warframe
# The Witcher
# Games + Demos
# Mega Man 11
# World of Tanks
# Super Mario Maker
# Euro Truck Simulator 2
# Twitch Sings
# Marbles On Stream
# Sea of Thieves
# Chess
# Detroit: Become Human
# Star Citizen
# osu!
# Mordhau
# Project Zomboid
# World of Warships
# Dark Souls III
# Tekken 7
# Final Fantasy: Brave Exvius
# Arma 3
# Heroes of Might and Magic III: The Shadow of Death
# Tom Clancy's The Division 2
# Monster Hunter World
# The King of Fighters All Star
# Golf With Your Friends
# Mega Man X
# Minion Masters
# Albion Online
# MLB The Show 19
# Realm Royale
# Super Castlevania IV
# Dungeons & Dragons
# Kerbal Space Program
# Battlefield V
# Dragon Ball FighterZ
# ROBLOX

# %%
from selenium.common.exceptions import *
# 'contains' will find a match on the text, in this case return b tag
game_list_cats = []

#this loop ends at retro games because retro games has no tag
num = 2
while num < 110: #s/b 110
    try:
        gross_selector = f'//*[@id="root"]/div/div[2]/div/main/div/div[3]/div/div/div/div[3]/div/div/div[1]/div[{num}]/div/div/div/div[2]'
        print(driver.find_element_by_xpath(gross_selector).text.split('\n'))
        game_list_cats.append(driver.find_element_by_xpath(gross_selector).text.split('\n'))
        time.sleep(.5+2*random.random())
        num+=1
    except NoSuchElementException:
        print(['ERROR'])
        game_list_cats.append(['RETROGAMEPLACEHOLDER'])
        time.sleep(.5+2*random.random())        
        num+=1
# Out:
# ['Shooter']
# ['MOBA']
# ['FPS', 'Shooter']
# ['Action', 'Driving/Racing Game', 'Open World']
# ['IRL']
# ['MMORPG']
# ['Action', 'Sports Game', 'Driving/Racing Game']
# ['MOBA']
# ['Shooter', 'FPS']
# ['FPS', 'Shooter']
# ['FPS', 'Shooter']
# ['Fighting', 'Platformer']
# ['Strategy', 'Card & Board Game']
# ['RTS', 'FPS', 'Shooter']
# ['FPS', 'Shooter']
# ['FPS', 'Shooter']
# ['Action']
# ['FPS', 'Shooter']
# ['Action', 'Horror']
# ['Action', 'Open World', 'Adventure Game']
# ['Strategy']
# ['Card & Board Game']
# ['MMORPG', 'Stealth', 'Open World']
# ['Card & Board Game']
# ['Creative']
# ['FPS', 'Shooter']
# ['Strategy', 'Action']
# ['Action', 'Adventure Game']
# ['Sports Game']
# ['IRL', 'Creative']
# ['Gambling Game']
# ['Sports Game']
# ['Simulation', 'FPS', 'Shooter']
# ['Action', 'RPG']
# ['Sports Game']
# ['MMORPG']
# ['Action', 'RPG', 'MMORPG']
# ['MMORPG']
# ['Action', 'Fighting']
# ['Action', 'RPG', 'Horror']
# ['Action']
# ['IRL']
# ['Shooter', 'Action', 'Adventure Game']
# ['RPG', 'Action', 'Open World']
# ['Action', 'Horror']
# ['RPG', 'Stealth', 'Open World']
# ['RTS', 'Strategy']
# ['ERROR']
# ['Strategy', 'RPG', 'Action']
# ['MMORPG', 'Open World', 'RPG']
# ['Horror', 'Indie Game']
# ['IRL']
# ['Adventure Game', 'Platformer']
# ['Creative', 'IRL']
# ['MMORPG', 'Adventure Game', 'RPG']
# ['Fighting']
# ['RPG', 'Simulation', 'FPS']
# ['Puzzle']
# ['Strategy', 'RTS']
# ['MOBA']
# ['RPG']
# ['Platformer']
# ['Simulation']
# ['Action']
# ['RPG', 'MMORPG']
# ['Compilation', 'FPS', 'Shooter']
# ['Simulation', 'RPG', 'Action']
# ['MOBA']
# ['Fighting']
# ['Puzzle', 'Indie Game']
# ['Card & Board Game']
# ['Action', 'Shooter']
# ['Action', 'RPG']
# ['Compilation', 'Puzzle', 'Action']
# ['Platformer']
# ['Simulation', 'Action']
# ['Platformer']
# ['Driving/Racing Game', 'Simulation']
# ['Rhythm & Music Game']
# ['ERROR']
# ['Action']
# ['Card & Board Game', 'Strategy']
# ['Adventure Game']
# ['Shooter', 'Action', 'Simulation']
# ['Rhythm & Music Game']
# ['Fighting', 'Indie Game']
# ['Simulation', 'RPG', 'Horror']
# ['Action', 'Simulation']
# ['RPG', 'Action', 'Series: Souls']
# ['Fighting']
# ['RPG']
# ['Simulation', 'FPS', 'Shooter']
# ['RPG', 'Strategy']
# ['RPG', 'Shooter', 'Open World']
# ['Action', 'RPG']
# ['RPG', 'Action']
# ['Sports Game', 'Horror']
# ['Shooter', 'Platformer']
# ['Strategy', 'RTS', 'Card & Board Game']
# ['MMORPG']
# ['Sports Game']
# ['Action', 'Shooter']
# ['Action', 'Platformer', 'Horror']
# ['RPG']
# ['Flight Simulator', 'Indie Game']
# ['Action', 'FPS', 'Shooter']
# ['Fighting']
# ['MMORPG', 'RPG']

# %%
games = []
for item in zip(game_list,game_list_cats):
    games.append(item)

# %%
games[0][1]
# Out:
# ['Shooter']

# %%
# driver.close() #closes the page

# %%
#selenium is more complex than BeautifulSoup but requires more work
